# %%
import charts
from bkcharts import Bar, output_file, show
from bokeh.io import output_notebook
from bokeh.plotting import figure
from bokeh.layouts import layout
from bkcharts import Donut
from bkcharts.utils import df_from_json
from bokeh.models.widgets import Div

import pandas as pd
from bokeh.layouts import widgetbox

import numpy as np
from bokeh.palettes import RdGy, PuBu

regions = charts.loadRegionData()
ages = charts.loadChartData()
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="51a692e5-5660-49a7-b27d-b05dbe63b551">Loading BokehJS ...</span>
#     </div>

# %%
""" Data Processing """
""" The number of Countries that data > 0 in each area"""

result0 = {}
for age in ages:
    tmp = regions.get(age[0])
    if tmp:
        if result0.get(tmp):
            result0[tmp] += 1
        else: result0[tmp] = 1
# print result0

result1 = {}
for age in ages:
    if age[1] > 0:
        tmp = regions.get(age[0])
        if tmp:
            if result1.get(tmp):
                result1[tmp] += 1
            else: result1[tmp] = 1
# print result1

# %%
""" CHART ONE: STACK BAR CHART """

tag = []
barName = []
billionaires = []

for key in result0.keys():
    tag.append("non-exists")
    tag.append("exists")
    barName.append(key)
    barName.append(key)
    billionaires.append(result1[key])
    billionaires.append(result0[key] - result1[key])

# print tag
# print barName
# print billionaires

# %%
div = Div(text="""The dataset I selected for the homework is <b>Average age of dollar billionaires (years)</b> and 
gaminder_regions.csv file. By using those two files, I could see the distribution of billionaires for each region 
and also see the change of each country's average age of billionaires. This data visualization would require some data
processing job first and then, use bokeh for plotting. The charts I tried contain stacked bar chart, pie chart, scatter
plot and line plot.""",
width=800, height=100)

show(widgetbox(div))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a2a58547-6c69-4d53-95f2-3c13a132f486"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("a2a58547-6c69-4d53-95f2-3c13a132f486");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a2a58547-6c69-4d53-95f2-3c13a132f486");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a2a58547-6c69-4d53-95f2-3c13a132f486' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"698336af-0f24-42c5-b980-c219930c826a":{"roots":{"references":[{"attributes":{"children":[{"id":"b129cf42-9a34-479d-bdec-7f5f288cb181","type":"Div"}]},"id":"113b7417-530e-4a56-9141-2e8c84cf5dc9","type":"WidgetBox"},{"attributes":{"height":100,"text":"The dataset I selected for the homework is <b>Average age of dollar billionaires (years)</b> and \ngaminder_regions.csv file. By using those two files, I could see the distribution of billionaires for each region \nand also see the change of each country's average age of billionaires. This data visualization would require some data\nprocessing job first and then, use bokeh for plotting. The charts I tried contain stacked bar chart, pie chart, scatter\nplot and line plot.","width":800},"id":"b129cf42-9a34-479d-bdec-7f5f288cb181","type":"Div"}],"root_ids":["113b7417-530e-4a56-9141-2e8c84cf5dc9"]},"title":"Bokeh Application","version":"0.12.7"}};
#             var render_items = [{"docid":"698336af-0f24-42c5-b980-c219930c826a","elementid":"a2a58547-6c69-4d53-95f2-3c13a132f486","modelid":"113b7417-530e-4a56-9141-2e8c84cf5dc9"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((root.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i].call(root, root.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!root._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         root._bokeh_failed_load = true;
#       } else if (force !== true) {
#         var cell = $(document.getElementById("a2a58547-6c69-4d53-95f2-3c13a132f486")).parents('.cell').data().cell;
#         cell.output_area.append_execute_result(NB_LOAD_WARNING)
#       }
#
#     }
#
#     if (root._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(window));
# </script>

# %%
data = {'tag': tag, 'barName': barName, 'billionaires':billionaires}
# print data
bar = Bar(data, values='billionaires', label='barName', stack='tag', agg='sum',
          title="The number of countries which have billionaires and not", legend='top_right', 
          plot_width=600, plot_height = 500, color=['#ff8080','#cc0000'])

"""Reference-Stacked Bar Chart: http://bokeh.pydata.org/en/0.12.0/docs/reference/charts.html"""

show(bar, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id
"1a238ba5-a7be-4c89-a650-d87cfe146f1e","type":"GlyphRenderer"},{"id":"a3bb8a0e-7a22-4834-8b50-9c9bda1ae9bc","type":"GlyphRenderer"},{"id":"069ba336-107a-4147-8c60-d963b89bc83e","type":"GlyphRenderer"},{"id":"c035616b-036f-4df8-a38a-1e45fd5f815b","type":"Legend"},{"id":"870bfc2e-4c29-433e-9bc2-9d81f78d2e9e","type":"CategoricalAxis"},{"id":"3e8f3970-fef7-464b-896b-1f353f4f2420","type":"LinearAxis"},{"id":"c06ae45b-dfd8-4671-b99d-7a510db7d780","type":"Grid"}],"title":{"id":"1bc02448-30c6-4332-989c-bd563d8dffa3","type":"Title"},"toolbar":{"id":"ec453a04-de78-440e-a0c9-fc4f232a6542","type":"Toolbar"},"x_range":{"id":"b699f3b9-ba66-4328-90ba-cd4e967fe67d","type":"FactorRange"},"x_scale":{"id":"5efd9555-6124-4b26-a7a9-fa3f622da813","type":"CategoricalScale"},"y_range":{"id":"25e92007-edea-4595-81df-0521ed40d893","type":"Range1d"},"y_scale":{"id":"28ba2d08-7998-420d-bc70-ea27ba30b7b7","type":"LinearScale"}},"id":"6a8fe11b-0562-4a76-855f-41b6ff0c0f1a","subtype":"Chart","type":"Plot"},{"attributes":{"source":null},"id":"fe75fbfc-2513-4983-bee1-ab54c1e914c2","type":"CDSView"},{"attributes":{"plot":null,"text":"The number of countries which have billionaires and not"},"id":"1bc02448-30c6-4332-989c-bd563d8dffa3","type":"Title"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","wid ...

# %%
""" CHART TWO: DONUT CHART """
"""Reference-Donut Chart: http://bokeh.pydata.org/en/0.12.0/docs/reference/charts.html"""

donutData = {'count': 241, 'object': 'list',
             'data': [{'name': 'East Asia & Pacific', 'numbers': {'total': 46, 'ex': 11, 'no-ex': 35}},
                      {'name': 'Sub-Saharan Africa', 'numbers': {'total': 50, 'ex': 1, 'no-ex': 49}},
                      {'name': 'Middle East & North Africa', 'numbers': {'total': 21, 'ex': 5, 'no-ex': 16}},
                      {'name': 'South Asia', 'numbers': {'total': 8, 'ex': 1, 'no-ex': 7}},
                      {'name': 'America', 'numbers': {'total': 51, 'ex': 8, 'no-ex': 43}},
                      {'name': 'Europe & Central Asia', 'numbers': {'total': 65, 'ex': 18, 'no-ex': 47}}]}

df = df_from_json(donutData)
df = df.sort_values(by="total", ascending=False)
df = pd.melt(df, id_vars=['name'],
             value_vars=['ex', 'no-ex'],
             value_name='medal_count', var_name='medal')

# Reference: Donut chart for medals - Bokeh
d = Donut(df, label=['name', 'medal'], values='medal_count',
          text_font_size='7pt', hover_text='country_count', plot_height=600, plot_width=600,
          title = 'Pie Chart for the number of countries which have billionaires',
          # color = PuBu)
          color=['#084594', '#2171b5', '#4292c6', '#6baed6', '#9ecae1', '#c6dbef', '#deebf7', '#f7fbff'])

show(d, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e1fe369c-21b1-4eb7-8366-3476a18ae84c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("e1fe369c-21b1-4eb7-8366-3476a18ae84c");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e1fe369c-21b1-4eb7-8366-3476a18ae84c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e1fe369c-21b1-4eb7-8366-3476a18ae84c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7f8b6bd3-c11e-4b52-9382-b68afd59d40e":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x","text_angle","text"],"data":{"text":["America","East Asia & Pacific","Europe & Central Asia","Middle East & North Africa","South Asia","Sub-Saharan Africa","ex","no-ex","ex","no-ex","ex","no-ex","ex","no-ex","ex","no-ex","ex","no-ex"],"text_angle":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
type":"AnnularWedge"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"fc94abaf-2409-42eb-9cec-d8d7ca24c02c","type":"CDSView"}},"id":"3dcd01b2-313b-40d8-9f42-f0005b4a44d9","type":"GlyphRenderer"},{"attributes":{},"id":"81506527-a01b-4ffb-8b7d-d7bc7fe460d7","type":"BasicTicker"},{"attributes":{"source":{"id":"507d5f30-99d8-43e4-ac5f-b88b59931a31","type":"ColumnDataSource"}},"id":"a7f45aeb-b155-4150-8df4-98701ca8f6b0","type":"CDSView"},{"attributes":{"axis_label":null,"formatter":{"id":"bc1b3fec-63a2-42d1-bd90-2b9f137019dd","type":"BasicTickFormatter"},"plot":{"id":"ffa90a6c-b090-45c0-8d3a-82c3015a9b83","subtype":"Chart","type":"Plot"},"ticker":{"id":"81506527-a01b-4ffb-8b7d-d7bc7fe460d7","type":"BasicTicker"},"visible ...

# %%
""" Chart Three: Scatter Plot """
""" Reference: https://bokeh.pydata.org/en/latest/docs/gallery/color_scatter.html"""
x, y, radius = charts.scatterData(ages, regions)
colors = ["#E6B8FF" for r in x]

TOOLS="hover, crosshair, pan, wheel_zoom, zoom_in, zoom_out, box_zoom, undo,\
       redo, reset, tap, save, box_select, poly_select, lasso_select,"

p_scatter = figure(tools=TOOLS, plot_width = 800, plot_height = 400, 
                   title = "Scatter Plot for the average age of billionaires for each country")

p_scatter.xaxis.axis_label = 'regions: East Asia & Pacific, Sub-Saharan Africa, Middle East & North Africa, South Asia, America, Europe & Central Asia' 
p_scatter.yaxis.axis_label = 'Average Age'

p_scatter.scatter(x, y, radius=radius,
          fill_color=colors, fill_alpha=0.9,
          line_color=None)

show(p_scatter)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="65688b17-3aac-4a04-9a02-9cbd20df5d69"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("65688b17-3aac-4a04-9a02-9cbd20df5d69");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("65688b17-3aac-4a04-9a02-9cbd20df5d69");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '65688b17-3aac-4a04-9a02-9cbd20df5d69' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8da63554-7638-4d70-ac4b-8a01a6943103":{"roots":{"references":[{"attributes":{},"id":"7791d7b7-5774-4769-a879-8c6e1e9aaec8","type":"ZoomInTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"06f983f9-29b3-4421-8b3e-d32f688f7708","type":"BoxAnnotation"},{"attributes":{},"id":"3e06c2a7-3b3d-422f-b8cb-253154ed1758","type":"CrosshairTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0598c87e-bf84-498f-b5e5-53269cf5ef5d","type":"HoverTool"},{"id":"3e06c2a7-3b3d-422f-b8cb-253154ed1758","type":"CrosshairTool"},{"id":"f6a9cb61-2533-4270-98f6-5302029b10c4","type":"PanTool"},{"id":"5d9fff8b-722a-4aa3-824c-a6845a87e3e2","type":"WheelZoomTool"},{"id":"7791d7b7-5774-4769-a879-8c6e1e9aaec8","type":"ZoomInTool"},{"id":"3b764e2e-2cd9-4aa9-9fbd-0165f89c4e0c","type":"ZoomOutTool"},{"id":"4dcdd605-9c9d-45a7-9bfd-b17d4cd8863c","type":"BoxZoomTool"},{"id":"c540d568-9610-40aa-b49e-32721d9b6b3b","type":"UndoTool"},{"id":"9b278ea2-9126-4e31-a9a0-58e7efe94c10","type":"RedoTool"},{"id":"3eef5171-dd3d-46bd-8b80-4d4875973033","type":"ResetTool"},{"id":"46683528-4fa9-490e-8068-282425831e40","type":"TapTool"},{"id":"ab57047d-1b93-4e55-be27-bb9279296ad0","type":"SaveTool"},{"id":"1582f787-fdec-485d-a494-4529d204f079","type":"BoxSelectTool"},{"id":"7d9c9606-1e44-4716-a2ce-2be9164a9f5f","type":"PolySelectTool"},{"id":"37022caa-bb8c-4f1b-9db7-3640ceef546b","type":"LassoSelectTool"}]},"id":"4b5defeb-cddc-4c77-9141-2458a982c832","type":"Toolbar"},{"attributes":{"callback":null},"id":"46683528-4fa9-490e-8068-282425831e40","type":"TapTool"},{"attributes":{"plot":{"id":"131365b2-2849-488b-9397-d7d70e92392c","subtype":"Figure","type":"Plot"},"ticker":{"id":"556f20c5-573a-4622-a769-0a43816ba540","type":"BasicTicker"}},"id":"7fd00918-c378-473f-aec7-056ff034a865","type":"Grid"},{"attributes":{"callback":null},"id":"0598c87e-bf84-498f-b5e5-53269cf5ef5d","type":"HoverTool"},{"attributes":{},"id":"fc22936b-f282-430f-ba25-21002bb02a78","type":"BasicTicker"},{"attributes":{},"id":"5d9fff8b-722a-4aa3-824c-a6845a87e3e2","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"100ff956-3457-4da0-95cc-126a573bae9b","type":"BoxAnnotation"},{"attributes":{},"id":"f6a9cb61-2533-4270-98f6-5302029b10c4","type":"PanTool"},{"attributes":{},"id":"9b278ea2-9126-4e31-a9a0-58e7efe94c10","type":"RedoTool"},{"attributes":{"source":{"id":"aec0fbd2-b136-4e07-8364-0d5f507050f8","type":"ColumnDataSource"}},"id":"f691233f-8653-49fc-8602-f0dcd5a00e3b","type":"CDSView"},{"attributes":{},"id":"f0ae9cfb-d34b-4c44-9625-efd759e0e54b","type":"LinearScale"},{"attributes":{"plot":null,"text":"Scatter Plot for the average age of billionaires for each country"},"id":"121973ee-4b9d-4c07-831d-ef0c376325bf","type":"Title"},{"attributes":{},"id":"3b764e2e-2cd9-4aa9-9fbd-0165f89c4e0c","type":"ZoomOutTool"},{"attributes":{"callback":null,"overlay":{"id":"863e4b29-ed10-45e3-856d-cfbe1db8aed1","type":"PolyAnnotation"}},"id":"7d9c9606-1e44-4716-a2ce-2be9164a9f5f","type":"PolySelectTool"},{"attributes":{"callback":null},"id":"da51a692-425d-4da1-b80d-0d57aff23619","type":"DataRange1d"},{"attributes":{},"id":"3eef5171-dd3d-46bd-8b80-4d4875973033","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"field":"radius","units":"data"},"x":{"field":"x ...

# %%
""" Chart Four: Line Plot"""
"""Reference Line: https://bokeh.pydata.org/en/latest/docs/gallery/stocks.html"""

p1 = figure(x_axis_type="linear", title="Average age of billionaires (Click legend for hiding lines)",
            plot_width = 1000)
p1.grid.grid_line_alpha=0.3
p1.xaxis.axis_label = 'Date'
p1.yaxis.axis_label = 'Average Age'

line = charts.lineData(ages)
# print line
tmp =  RdGy.values()
lineColor = []
for colorlist in tmp:
    lineColor += colorlist
# print lineColor

i = 0
for key in line.keys():
    p1.line([2004, 2005, 2006, 2007], line[key], color = lineColor[i], legend = key)
    i += 1

p1.legend.location = "top_left"
p1.legend.click_policy="hide"

show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="41c70fe6-845c-40b3-9e48-7d4787e95b89"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("41c70fe6-845c-40b3-9e48-7d4787e95b89");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("41c70fe6-845c-40b3-9e48-7d4787e95b89");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '41c70fe6-845c-40b3-9e48-7d4787e95b89' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7ab4fdb4-e778-4989-85d0-43105b010f7a":{"roots":{"references":[{"attributes":{"data_source":{"id":"666e77e0-cac2-4ca6-9f8e-2d8dd2926fc9","type":"ColumnDataSource"},"glyph":{"id":"d016daae-d23a-4a95-8633-9758340eb404","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":